# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
brain_size = pd.read_csv('brain_size.csv')

print(brain_size)
print(brain_size.shape)
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]
# (237, 4)

# %%
#X = brain_size.iloc[:,[2]]
#y = brain_size.iloc[:,[3]]

# %%
X = brain_size['Head Size(cm^3)'].values.reshape(-1,1)
y = brain_size['Brain Weight(grams)'].values.reshape(-1,1)

# %%
plt.scatter(X, y, c='blue', label='Data Point')
plt.title('Model Fits to the Data')  
plt.xlabel('Head Size (cm^3)')  
plt.ylabel('Brain Weight (grams)')  
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (189, 1)
# (48, 1)
# (189, 1)
# (48, 1)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X, y, c='blue', label='Data Point')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.title('Model Fits to the Data')  
plt.xlabel('Head Size (cm^3)')  
plt.ylabel('Brain Weight (grams)')  
plt.legend()
plt.show()
